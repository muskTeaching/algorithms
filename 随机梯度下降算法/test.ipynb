# %%
import numpy as np

# %%
a=np.linspace(-5,5,12)

# %%
def calculate(n):
    sum=0
    for i in range(n):
        sum+=i if not (i%7==0 or i%11==0) else 0
    print(sum)
calculate(10000)
# Out:
# 38948958

# %%
b=12
def f(m):
    c=m+1
    m=c
    print(m)
f(b)
print(b)
# Out:
# 13
# 12
